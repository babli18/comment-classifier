# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import string
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
df = pd.read_csv('results/filtered_netflix_reviews_language.csv')

# %%
# Download required NLTK resources
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('omw-1.4')  # For token normalization if needed

# Define stop words
stop_words = set(stopwords.words('english'))

# Emoji pattern
def remove_emojis(text):
    emoji_pattern = re.compile(
        "[\U0001F600-\U0001F64F]|"  # emoticons
        "[\U0001F300-\U0001F5FF]|"  # symbols & pictographs
        "[\U0001F680-\U0001F6FF]|"  # transport & map symbols
        "[\U0001F1E0-\U0001F1FF]"    # flags (iOS)
        "[\u2600-\u26FF]|"          # Miscellaneous symbols
        "[\u2700-\u27BF]",           # Dingbats
        flags=re.UNICODE
    )
    return emoji_pattern.sub(r"", text)

# Text preprocessing function
def preprocess_text(text):
    try:
        # Ensure text is a string
        text = str(text)

        # Handle encoding issues by replacing surrogate characters
        text = text.encode('utf-8', 'replace').decode('utf-8')

        # Convert to lowercase
        text = text.lower()
        
        # Remove URLs
        text = re.sub(r'http\S+|www\.\S+', '', text)

        # Remove Twitter handles
        text = re.sub(r'@\w+', '', text)

        # Remove punctuation
        text = text.translate(str.maketrans('', '', string.punctuation))

        # Remove emojis
        text = remove_emojis(text)

        # Tokenize text
        tokens = word_tokenize(text)

        # Remove stop words
        tokens = [word for word in tokens if word not in stop_words]

        # Join the tokens back into a string
        processed_text = ' '.join(tokens)

        return processed_text

    except Exception as e:
        print(f"Error processing text: {e}")
        return ''  # Return an empty string in case of errors

# Apply preprocessing to a DataFrame column
def preprocess_dataframe(df, column_name):
    df['preprocess_content'] = df[column_name].apply(preprocess_text)
    return df


# Preprocess the 'content' column of the DataFrame
processed_df = preprocess_dataframe(df, 'content')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Babli
# [nltk_data]     Dey\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\Babli
# [nltk_data]     Dey\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to C:\Users\Babli
# [nltk_data]     Dey\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
processed_df
# Out:
#                                     reviewId                userName  \
# 0       6fcd7344-d13e-46f5-ac98-d0ebec6ecb3b             ayuni ayuni
# 1       de92d64e-999b-4cbd-8487-518126fe0629  goat and birds channel
# 2       754c9b1e-9bfa-4c23-b658-8a8804033265         Prashanth Annam
# 3       258242e4-ba13-4233-88a0-147c721fd65f           Shubham Kadam
# 4       b113fac2-503f-4acf-8480-4f099e7706be           Jahnavi Reddy
# ...                                      ...                     ...
# 123508  a760ead9-e7aa-4ed1-a651-5c37c3600dac           A Google user
# 123509  4957f9e7-d7f4-4a52-9764-031cebcac83f            Captain Jeoy
# 123510  9acf7586-7abf-4b50-8c50-3ede3b2a42c4                Suryansh
# 123511  32870f7f-c461-4256-b602-75244ca60248           A Google user
# 123512  dc1352e9-10a8-41ca-ab23-05d045b08e90              suraj soni
#
#                                                   content  score  \
# 0       Can you prolong Big bang theory series in Netf...      5
# 1                                                NICE APP      5
# 2                                                West app      1
# 3       Primium mat maro जो movie चाहिय ओ नही मिलती मे...      1
# 4       This APP IS VERY GOOD INFACT ULTIMATE I even d...      5
# ...                                                   ...    ...
# 123508  i really like it! there are so many movies and...      5
# 123509   I love Netflix. I always enjoy my time using it.      5
# 123510               Sound quality is very slow of movies      1
# 123511  Rate is very expensive.. bcos we see netflix s...      1
# 123512  this app is awesome for english movies ,series...      4
#
#         thumbsUpCount                 date  year  month  day language  \
# 0                   0  2024-12-31 15:43:14  2024     12   31       en
# 1                   0  2024-12-31 15:42:23  2024     12   31       it
# 2                   0  2024-12-31 15:38:05  2024     12   31       en
# 3                   0  2024-12-31 15:35:33  2024     12   31       hi
# 4                   0  2024-12-31 15:34:33  2024     12   31       en
# ...               ...                  ...   ...    ...  ...      ...
# 123508              0  2019-08-03 15:06:03  2019      8    3       en
# 123509              0  2022-08-15 16:16:30  2022      8   15       en
# 123510              0  2020-08-17 07:26:58  2020      8   17       en
# 123511              0  2019-07-21 09:41:42  2019      7   21       en
# 123512              0  2020-05-24 11:04:08  2020      5   24       en
#
#                                        preprocess_content
# 0                  prolong big bang theory series netflix
# 1                                                nice app
# 2                                                west app
# 3       primium mat maro जो movie चाहिय ओ नही मिलती मे...
# 4       app good infact ultimate even downloaded tv al...
# ...                                                   ...
# 123508              really like many movies kdramas watch
# 123509               love netflix always enjoy time using
# 123510                          sound quality slow movies
# 123511  rate expensive bcos see netflix sunday charged...
# 123512          app awesome english movies series tv show
#
# [123513 rows x 11 columns]

# %%
import torch
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from langdetect import detect

# Load the tokenizer and model
tokenizer = AutoTokenizer.from_pretrained("Helsinki-NLP/opus-mt-mul-en")
model = AutoModelForSeq2SeqLM.from_pretrained("Helsinki-NLP/opus-mt-mul-en")

# Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# Function to detect language
def detect_language(text):
    try:
        return detect(text)
    except:
        return "unknown"

# Function to translate text to English
def translate_to_english(text, detected_lang):
    # If language is English, return the text as is
    if detected_lang == "en":
        return text
    try:
        # Tokenize the input text
        inputs = tokenizer.encode(text, return_tensors="pt", truncation=True).to(device)
        
        # Generate translation
        outputs = model.generate(inputs, max_length=512, num_beams=5, early_stopping=True)
        
        # Decode the output
        translated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
        return translated_text
    except Exception as e:
        return f"Translation failed: {e}"

# Add detected language and translation columns
processed_df["language_hel"] = processed_df["preprocess_content"].apply(detect_language)
processed_df["translated"] = processed_df.apply(
    lambda row: translate_to_english(row["preprocess_content"], row["language_hel"]), axis=1
)
# Out:
# c:\Users\Babli Dey\anaconda3\Lib\site-packages\transformers\models\marian\tokenization_marian.py:194: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# c:\Users\Babli Dey\anaconda3\Lib\site-packages\transformers\utils\generic.py:260: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(

# %%
processed_df[processed_df["language_hel"] != "en"]
# Out:
#                                     reviewId                userName  \
# 1       de92d64e-999b-4cbd-8487-518126fe0629  goat and birds channel
# 3       258242e4-ba13-4233-88a0-147c721fd65f           Shubham Kadam
# 5       43794861-0f4a-4e5e-95e5-197c1ba643cb          Basudev Hansda
# 7       d40c0dbd-b85b-4734-bc96-74725a144f62              Marc Human
# 8       1d42e2e0-34ae-4d27-8e14-64f1321e4c33          Anshika Bansal
# ...                                      ...                     ...
# 123495  200037e7-5836-43aa-a85e-18a9ca2e1927           Nishtha Bisht
# 123497  4293dedc-e5a3-47a4-8350-8326a90abe33                 Dave jc
# 123502  3759168b-2cfd-4719-824f-61bcf0082965         Manjunath Manju
# 123504  5f68b545-1079-4a57-9024-fc6e27d7db96               AD Basson
# 123505  9996579a-cf67-40a6-94eb-9ccd63c7d46a           dady mon mari
#
#                                                   content  score  \
# 1                                                NICE APP      5
# 3       Primium mat maro जो movie चाहिय ओ नही मिलती मे...      1
# 5       🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀...      5
# 7                                                    Best      5
# 8          Amazing customer support and good application.      5
# ...                                                   ...    ...
# 123495                Netflix app isn't opening up at all      2
# 123497                       Does not have kannada movies      1
# 123502  Their is no position for kannada language , do...      1
# 123504                                The. Best App. Ever      2
# 123505  How can I delete one of the users? Please. Hel...      3
#
#         thumbsUpCount                 date  year  month  day language  \
# 1                   0  2024-12-31 15:42:23  2024     12   31       it
# 3                   0  2024-12-31 15:35:33  2024     12   31       hi
# 5                   0  2024-12-31 15:29:42  2024     12   31       ur
# 7                   0  2024-12-31 15:09:09  2024     12   31       en
# 8                   0  2024-12-31 14:56:34  2024     12   31       en
# ...               ...                  ...   ...    ...  ...      ...
# 123495              0  2021-11-14 14:16:04  2021     11   14       en
# 123497              0  2024-03-17 19:13:46  2024      3   17       en
# 123502              0  2024-03-17 15:19:57  2024      3   17       en
# 123504              0  2024-04-01 10:21:15  2024      4    1       en
# 123505              0  2024-03-01 04:54:36  2024      3    1       en
#
#                                        preprocess_content language_hel  \
# 1                                                nice app           it
# 3       primium mat maro जो movie चाहिय ओ नही मिलती मे...           hi
# 5       🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀...      unknown
# 7                                                    best           af
# 8               amazing customer support good application           it
# ...                                                   ...          ...
# 123495                           netflix app isnt opening           no
# 123497                                     kannada movies           sk
# 123502                 position kannada language consider           es
# 123504                                      best app ever           no
# 123505                       delete one users please help           nl
#
#                                                translated
# 1                                                Nice app
# 3       Premium mat maro which should be filmed if it ...
# 5                                              I'm sorry.
# 7                                                    best
# 8               amazing customer support good application
# ...                                                   ...
# 123495                                netflix app is open
# 123497                               Can not open message
# 123502                                    candid position
# 123504                                      best app ever
# 123505                        please remove one user help
#
# [14047 rows x 13 columns]

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("google-t5/t5-base")
model = AutoModelForSeq2SeqLM.from_pretrained("google-t5/t5-base")

# %%
import torch
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from langdetect import detect

# Load the tokenizer and model
tokenizer = AutoTokenizer.from_pretrained("google-t5/t5-base")
model = AutoModelForSeq2SeqLM.from_pretrained("google-t5/t5-base")

# Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# Function to detect language
def detect_language(text):
    try:
        return detect(text)
    except:
        return "unknown"

# Function to translate text to English
def translate_to_english(text, detected_lang):
    # If language is English, return the text as is
    if detected_lang == "en":
        return text
    try:
        # T5 expects a specific task prefix for translation
        task_prefix = f"translate {detected_lang} to English: "
        input_text = task_prefix + text

        # Tokenize the input text
        inputs = tokenizer.encode(input_text, return_tensors="pt", truncation=True).to(device)
        
        # Generate translation
        outputs = model.generate(inputs, max_length=512, num_beams=5, early_stopping=True)
        
        # Decode the output
        translated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
        return translated_text
    except Exception as e:
        return f"Translation failed: {e}"

# Add detected language and translation columns
processed_df["language_t5"] = processed_df["preprocess_content"].apply(detect_language)
processed_df["translated_t5"] = processed_df.apply(
    lambda row: translate_to_english(row["preprocess_content"], row["language_t5"]), axis=1
)
# Out:
# Downloading config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# c:\Users\Babli Dey\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:133: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Babli Dey\.cache\huggingface\hub. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Downloading spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/892M [00:00<?, ?B/s]
# Downloading generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.

# %%
processed_df[processed_df["language_t5"] != "en"]
# Out:
#                                     reviewId                userName  \
# 1       de92d64e-999b-4cbd-8487-518126fe0629  goat and birds channel
# 3       258242e4-ba13-4233-88a0-147c721fd65f           Shubham Kadam
# 5       43794861-0f4a-4e5e-95e5-197c1ba643cb          Basudev Hansda
# 6       39923caa-1af7-4123-859f-76087131ce1c              Joy Sadang
# 7       d40c0dbd-b85b-4734-bc96-74725a144f62              Marc Human
# ...                                      ...                     ...
# 123491  be0b7765-422b-42e8-bc6c-1d93200963ec          Joshua Jameson
# 123497  4293dedc-e5a3-47a4-8350-8326a90abe33                 Dave jc
# 123502  3759168b-2cfd-4719-824f-61bcf0082965         Manjunath Manju
# 123504  5f68b545-1079-4a57-9024-fc6e27d7db96               AD Basson
# 123505  9996579a-cf67-40a6-94eb-9ccd63c7d46a           dady mon mari
#
#                                                   content  score  \
# 1                                                NICE APP      5
# 3       Primium mat maro जो movie चाहिय ओ नही मिलती मे...      1
# 5       🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀...      5
# 6       The app Is very good i just don't like about I...      4
# 7                                                    Best      5
# ...                                                   ...    ...
# 123491                                    I'm enjoying 😎🎧      5
# 123497                       Does not have kannada movies      1
# 123502  Their is no position for kannada language , do...      1
# 123504                                The. Best App. Ever      2
# 123505  How can I delete one of the users? Please. Hel...      3
#
#         thumbsUpCount                 date  year  month  day language  \
# 1                   0  2024-12-31 15:42:23  2024     12   31       it
# 3                   0  2024-12-31 15:35:33  2024     12   31       hi
# 5                   0  2024-12-31 15:29:42  2024     12   31       ur
# 6                   0  2024-12-31 15:28:40  2024     12   31       en
# 7                   0  2024-12-31 15:09:09  2024     12   31       en
# ...               ...                  ...   ...    ...  ...      ...
# 123491              0  2024-05-02 07:53:48  2024      5    2       en
# 123497              0  2024-03-17 19:13:46  2024      3   17       en
# 123502              0  2024-03-17 15:19:57  2024      3   17       en
# 123504              0  2024-04-01 10:21:15  2024      4    1       en
# 123505              0  2024-03-01 04:54:36  2024      3    1       en
#
#                                        preprocess_content language_hel  \
# 1                                                nice app           it
# 3       primium mat maro जो movie चाहिय ओ नही मिलती मे...           hi
# 5       🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀🫀...      unknown
# 6       app good dont like dont enough season watch be...           en
# 7                                                    best           af
# ...                                                   ...          ...
# 123491                                        im enjoying           hr
# 123497                                     kannada movies           sk
# 123502                 position kannada language consider           es
# 123504                                      best app ever           no
# 123505                       delete one users please help           nl
#
#                                                translated language_t5  \
# 1                                                Nice app          it
# 3       Premium mat maro which should be filmed if it ...          hi
# 5                                              I'm sorry.     unknown
# 6       app good dont like dont enough season watch be...          af
# 7                                                    best          af
# ...                                                   ...         ...
# 123491                                        im enjoying          hr
# 123497                               Can not open message          sk
# 123502                                    candid position          id
# 123504                                      best app ever          no
# 123505                        please remove one user help          nl
#
#                                             translated_t5
# 1                                                nice app
# 3                                                     ...
# 5
# 6       app good dont like dont enough season watch be...
# 7                                                    best
# ...                                                   ...
# 123491                                     hr im enjoying
# 123497                                  sk kannada movies
# 123502                 position kannada language consider
# 123504                                      best app ever
# 123505              nl löschen eine Benutzer bitte helfen
#
# [14134 rows x 15 columns]
